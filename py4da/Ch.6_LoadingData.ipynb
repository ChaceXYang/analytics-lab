# %%
import pandas as pd
import numpy as np

# %%
# !cat examples/ex1.csv
# Out:
# 'cat' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %%
df = pd.resd_csv("examples/ex1.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.resd_csv("examples/ex1.csv")
#
# AttributeError: module 'pandas' has no attribute 'resd_csv'
