# %%
import pandas as pd

# %%
import numpy as np

# %%
from datetime import datetime

# %%
now = datetime.now()

# %%
now
# Out:
# datetime.datetime(2026, 8, 15, 13, 59, 48, 730355)

# %%
now.year, now.month, now.day
# Out:
# (2026, 8, 15)

# %%
delta = datetime(2026, 8, 14, 14, 1, 12, 239884) - datetime(2002, 6, 6, 11, 45)

# %%
delta
# Out:
# datetime.timedelta(days=8835, seconds=8172, microseconds=239884)

# %%
delta.days
# Out:
# 8835

# %%
delta.seconds
# Out:
# 8172

# %%
from datetime import timedelta

# %%
start = datetime(2011, 1, 7)

# %%
start + timedelta(12)
# Out:
# datetime.datetime(2011, 1, 19, 0, 0)

# %%
start - 2*timedelta(12)
# Out:
# datetime.datetime(2010, 12, 14, 0, 0)

# %%
stamp = datetime(2011, 1, 3)

# %%
str(stamp)
# Out:
# '2011-01-03 00:00:00'

# %%
stamp.strftime("%Y-%m-%d")
# Out:
# '2011-01-03'

# %%
stamp.strftime("%F")
# Out:
# '2011-01-03'

# %%
value = "2011-01-03"

# %%
datetime.strptime(value, "%Y-%m-%d")
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)

# %%
datestrs = ["7/6/2011", "8/6/2011"]

# %%
[datetime.strptime(x, "%m/%d/%Y") for x in datestrs]
# Out:
# [datetime.datetime(2011, 7, 6, 0, 0), datetime.datetime(2011, 8, 6, 0, 0)]

# %%
datestrs = ["2011-07-06 12:00:00", "2011-08-06 00:00:00"]

# %%
pd.to_datetime(datestrs)
# Out:
# DatetimeIndex(['2011-07-06 12:00:00', '2011-08-06 00:00:00'], dtype='datetime64[ns]', freq=None)

# %%
idx = pd.to_datetime(datestrs+[None])

# %%
idx
# Out:
# DatetimeIndex(['2011-07-06 12:00:00', '2011-08-06 00:00:00', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
idx[2]
# Out:
# NaT

# %%
pd.isna(idx)
# Out:
# array([False, False,  True])

# %% [markdown]
# # 11.2 Time Series Basics

# %%
dates = [datetime(2011, 1, 2), datetime(2011, 1, 5),
         datetime(2011, 1, 7), datetime(2011, 1, 8),
         datetime(2011, 1, 10), datetime(2011, 1, 12)]

# %%
ts = pd.Series(np.random.standard_normal(6), index = dates)

# %%
ts
# Out:
# 2011-01-02    1.133134
# 2011-01-05    0.304177
# 2011-01-07    0.477914
# 2011-01-08    0.983747
# 2011-01-10   -0.178698
# 2011-01-12    0.800289
# dtype: float64

# %%
ts.index
# Out:
# DatetimeIndex(['2011-01-02', '2011-01-05', '2011-01-07', '2011-01-08',
#                '2011-01-10', '2011-01-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
ts + ts[::2]
# Out:
# 2011-01-02    2.266268
# 2011-01-05         NaN
# 2011-01-07    0.955828
# 2011-01-08         NaN
# 2011-01-10   -0.357396
# 2011-01-12         NaN
# dtype: float64

# %%
ts.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
stamp = ts.index[0]

# %%
stamp
# Out:
# Timestamp('2011-01-02 00:00:00')

# %%
stamp = ts.index[2]

# %%
ts[stamp]
# Out:
# np.float64(0.4779141524530353)

# %%
ts["2011-01-10"]
# Out:
# np.float64(-0.17869784398901165)

# %%
loner_ts = pd.Series(np.random.standard_normal(1000), 
                     index = pd.date_range("2000-01-01", periods = 1000))

# %%
loner_ts
# Out:
# 2000-01-01    0.140746
# 2000-01-02   -0.866265
# 2000-01-03    0.371502
# 2000-01-04   -0.318147
# 2000-01-05   -1.566778
#                 ...
# 2002-09-22   -0.130352
# 2002-09-23   -1.516835
# 2002-09-24    0.274358
# 2002-09-25    0.566491
# 2002-09-26    0.410376
# Freq: D, Length: 1000, dtype: float64

# %%
loner_ts["2001"]
# Out:
# 2001-01-01   -0.148286
# 2001-01-02    0.598754
# 2001-01-03   -3.008394
# 2001-01-04   -1.108561
# 2001-01-05   -1.251757
#                 ...
# 2001-12-27    0.379768
# 2001-12-28    0.480862
# 2001-12-29    0.132531
# 2001-12-30   -0.906635
# 2001-12-31   -2.616024
# Freq: D, Length: 365, dtype: float64

# %%
loner_ts["2001-05"]
# Out:
# 2001-05-01    1.955576
# 2001-05-02   -1.306269
# 2001-05-03    0.628558
# 2001-05-04    1.548823
# 2001-05-05   -0.326492
# 2001-05-06   -1.256394
# 2001-05-07    0.535576
# 2001-05-08   -0.117967
# 2001-05-09    0.856061
# 2001-05-10   -0.221876
# 2001-05-11   -1.019946
# 2001-05-12    0.747948
# 2001-05-13    1.087357
# 2001-05-14   -0.172552
# 2001-05-15    0.398360
# 2001-05-16    0.234963
# 2001-05-17   -0.001967
# 2001-05-18   -0.118708
# 2001-05-19   -0.339471
# 2001-05-20    0.412423
# 2001-05-21   -0.193655
# 2001-05-22   -0.680893
# 2001-05-23   -0.538659
# 2001-05-24    0.247876
# 2001-05-25   -1.651669
# 2001-05-26   -0.601234
# 2001-05-27   -0.159371
# 2001-05-28   -0.830807
# 2001-05-29   -1.100129
# 2001-05-30    0.083799
# 2001-05-31    0.958427
# Freq: D, dtype: float64

# %%
ts[datetime(2011, 1, 7):]
# Out:
# 2011-01-07    0.477914
# 2011-01-08    0.983747
# 2011-01-10   -0.178698
# 2011-01-12    0.800289
# dtype: float64

# %%
ts[datetime(2011, 1, 7):datetime(2011, 1, 10)]
# Out:
# 2011-01-07    0.477914
# 2011-01-08    0.983747
# 2011-01-10   -0.178698
# dtype: float64

# %%
ts
# Out:
# 2011-01-02    1.133134
# 2011-01-05    0.304177
# 2011-01-07    0.477914
# 2011-01-08    0.983747
# 2011-01-10   -0.178698
# 2011-01-12    0.800289
# dtype: float64

# %%
ts["2011-01-06":"2011-01-11"]
# Out:
# 2011-01-07    0.477914
# 2011-01-08    0.983747
# 2011-01-10   -0.178698
# dtype: float64

# %%
ts.truncate(after = "2011-01-09")
# Out:
# 2011-01-02    1.133134
# 2011-01-05    0.304177
# 2011-01-07    0.477914
# 2011-01-08    0.983747
# dtype: float64

# %%
dates = pd.date_range("2000-01-01", periods=100, freq="W-WED")

# %%
long_df = pd.DataFrame(np.random.standard_normal((100,4)), 
                       index = dates, 
                       columns = ["Colorado", "Texas","New York", "Ohio"])

# %%
long_df
# Out:
#             Colorado     Texas  New York      Ohio
# 2000-01-05  0.288443  0.644099 -1.244593  0.561142
# 2000-01-12  1.138183  0.029686 -1.220206 -0.975049
# 2000-01-19  0.929688  0.847800 -1.306498  2.266271
# 2000-01-26  1.143182  1.696868  0.197715 -0.350162
# 2000-02-02 -0.455251  0.241052  1.313914 -0.910485
# ...              ...       ...       ...       ...
# 2001-10-31 -0.019457 -1.695726  1.393172 -2.065254
# 2001-11-07 -0.816595 -0.596299 -0.327603 -0.759640
# 2001-11-14  0.615807 -0.380830  1.797257 -0.895879
# 2001-11-21 -0.026911  1.903264 -1.850042 -1.013632
# 2001-11-28  0.465693 -1.708821  0.008074  1.513924
#
# [100 rows x 4 columns]

# %%
dates = pd.DatetimeIndex(["2000-01-01", "2000-01-02", "2000-01-02",
                          "2000-01-02", "2000-01-03"])

# %%
dup_ts = pd.Series(np.arange(5), index=dates)

# %%
dup_ts
# Out:
# 2000-01-01    0
# 2000-01-02    1
# 2000-01-02    2
# 2000-01-02    3
# 2000-01-03    4
# dtype: int64

# %%
dup_ts.index.is_unique
# Out:
# False

# %%
dup_ts["2000-01-02"] #不重复
# Out:
# 2000-01-02    1
# 2000-01-02    2
# 2000-01-02    3
# dtype: int64

# %%
dup_ts["2000-01-02"] #重复
# Out:
# 2000-01-02    1
# 2000-01-02    2
# 2000-01-02    3
# dtype: int64

# %%
grouped = dup_ts.groupby(level = 0)

# %%
grouped.mean()
# Out:
# 2000-01-01    0.0
# 2000-01-02    2.0
# 2000-01-03    4.0
# dtype: float64

# %%
grouped.count()
# Out:
# 2000-01-01    1
# 2000-01-02    3
# 2000-01-03    1
# dtype: int64

# %% [markdown]
# # 11.3 Date Ranges, Frequencies, and Shifting

# %%
ts
# Out:
# 2011-01-02    1.133134
# 2011-01-05    0.304177
# 2011-01-07    0.477914
# 2011-01-08    0.983747
# 2011-01-10   -0.178698
# 2011-01-12    0.800289
# dtype: float64

# %%
resampler = ts.resample("D")

# %%
resampler

# %%
index = pd.date_range("2012-04-01", "2012-06-01")

# %%
index
# Out:
# DatetimeIndex(['2012-04-01', '2012-04-02', '2012-04-03', '2012-04-04',
#                '2012-04-05', '2012-04-06', '2012-04-07', '2012-04-08',
#                '2012-04-09', '2012-04-10', '2012-04-11', '2012-04-12',
#                '2012-04-13', '2012-04-14', '2012-04-15', '2012-04-16',
#                '2012-04-17', '2012-04-18', '2012-04-19', '2012-04-20',
#                '2012-04-21', '2012-04-22', '2012-04-23', '2012-04-24',
#                '2012-04-25', '2012-04-26', '2012-04-27', '2012-04-28',
#                '2012-04-29', '2012-04-30', '2012-05-01', '2012-05-02',
#                '2012-05-03', '2012-05-04', '2012-05-05', '2012-05-06',
#                '2012-05-07', '2012-05-08', '2012-05-09', '2012-05-10',
#                '2012-05-11', '2012-05-12', '2012-05-13', '2012-05-14',
#                '2012-05-15', '2012-05-16', '2012-05-17', '2012-05-18',
#                '2012-05-19', '2012-05-20', '2012-05-21', '2012-05-22',
#                '2012-05-23', '2012-05-24', '2012-05-25', '2012-05-26',
#                '2012-05-27', '2012-05-28', '2012-05-29', '2012-05-30',
#                '2012-05-31', '2012-06-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start = "2012-04-01", periods = 20)
# Out:
# DatetimeIndex(['2012-04-01', '2012-04-02', '2012-04-03', '2012-04-04',
#                '2012-04-05', '2012-04-06', '2012-04-07', '2012-04-08',
#                '2012-04-09', '2012-04-10', '2012-04-11', '2012-04-12',
#                '2012-04-13', '2012-04-14', '2012-04-15', '2012-04-16',
#                '2012-04-17', '2012-04-18', '2012-04-19', '2012-04-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(end="2012-06-01", periods = 20)
# Out:
# DatetimeIndex(['2012-05-13', '2012-05-14', '2012-05-15', '2012-05-16',
#                '2012-05-17', '2012-05-18', '2012-05-19', '2012-05-20',
#                '2012-05-21', '2012-05-22', '2012-05-23', '2012-05-24',
#                '2012-05-25', '2012-05-26', '2012-05-27', '2012-05-28',
#                '2012-05-29', '2012-05-30', '2012-05-31', '2012-06-01'],
#               dtype='datetime64[ns]', freq='D')
